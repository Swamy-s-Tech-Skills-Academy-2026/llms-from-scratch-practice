# %% [markdown]
# # Byte Pair Encoding (BPE) Tokenizer From Scratch -- Simple

# %% [markdown]
# - I built this notebook as a minimal BPE implementation so I can learn the algorithm step-by-step.
# - My focus here is intuition and inspectability rather than feature completeness.
# - I relate it to my Chapter 2 tokenization learning path and compare behavior with practical tokenizers.
# - Useful references for validation: OpenAI GPT-2 tokenizer code and the `tiktoken` library.
# - I also keep the original compression perspective of BPE in mind while adapting it to LLM tokenization.
# - This notebook includes merge learning from scratch so I can observe how vocabulary grows.
# - For compact pedagogical code style, this version stays intentionally lightweight.

# %% [markdown]
# **This notebook intentionally keeps the implementation minimal for learning. For a fuller and more feature-rich version, I use [bpe-from-scratch.ipynb](bpe-from-scratch.ipynb).**

# %% [markdown]
# &nbsp;
# # 1. The main idea behind byte pair encoding (BPE)

# %% [markdown]
# - My core idea for BPE: convert text into token IDs that can be more compact than strict character-level encoding for LLM training.
#
# *[Figure from the book — see book or companion site for diagram.]*

# %% [markdown]
# &nbsp;
# ## 1.1 Bits and bytes

# %% [markdown]
# - Before merges, I anchor the concept in raw bytes.
# - Since BPE begins from byte-level symbols, I first convert text to UTF-8 bytes:

# %%
text = "This is some text"
byte_ary = bytearray(text, "utf-8")
print(byte_ary)

# %% [markdown]
# - Converting `bytearray` to `list` shows each byte as an integer, which is my starting ID representation.

# %%
ids = list(byte_ary)
print(ids)

# %% [markdown]
# - Byte IDs can already feed embeddings, so they are valid tokenizer outputs.
# - The downside is sequence length: near character-level granularity creates many IDs.
# - Even short text can produce a relatively long token list in this raw form.

# %%
print("Number of characters:", len(text))
print("Number of token IDs:", len(ids))

# %% [markdown]
# - In practical LLM tokenization, frequent pieces become subwords/words, so token count usually drops.
# - For "This is some text", GPT-2 style tokenization yields fewer IDs than byte-level encoding.
# - I can verify this quickly with the tokenizer viewer or `tiktoken`.
#
# *[Figure from the book — see book or companion site for diagram.]*
#
# ```python
# import tiktoken
#
# gpt2_tokenizer = tiktoken.get_encoding("gpt2")
# gpt2_tokenizer.encode("This is some text")
# # prints [1212, 318, 617, 2420]
# ```

# %% [markdown]
# - A single byte has 8 bits, so the base symbol range is 0..255.
# - Python confirms this boundary if I try to create byte values outside that range.
# - This is why BPE commonly starts from byte-level IDs before learning merged tokens.
#
# ```python
# import tiktoken
# gpt2_tokenizer = tiktoken.get_encoding("gpt2")
#
# for i in range(300):
#     decoded = gpt2_tokenizer.decode([i])
#     print(f"{i}: {decoded}")
# """
# prints:
# 0: !
# 1: "
# 2: #
# ...
# 255: �  # <---- single-character byte-level region
# 256:  t
# 257:  a
# ...
# 298: ent
# 299:  n
# """
# ```

# %% [markdown]
# - I notice IDs above 255 can already represent multi-character patterns in GPT-2-style vocabularies, which reflects design choices layered on top of byte initialization.

# %% [markdown]
# &nbsp;
# ## 1.2 Building the vocabulary

# %% [markdown]
# - During BPE training, I want the vocabulary to capture recurring subword units (for example `ent`) and sometimes full words when frequency justifies it.
#
# ```
# 318: is
# 617: some
# 1212: This
# 2420: text
# ```

# %% [markdown]
# - I connect this notebook to the original compression roots of BPE, then focus on the LLM version of the same idea.
# - Before coding, I keep a compact mental checklist: learn merges from data, apply merges in order, and decode by expansion.

# %% [markdown]
# &nbsp;
# ## 1.3 BPE algorithm outline
#
# **1. Count adjacent pairs**
# - I count neighboring token pairs and select the most frequent pair in the current sequence.
#
# **2. Merge and register**
# - I assign a fresh token ID to that pair and store the merge rule.
# - Merge order matters, because that order defines priority during encoding.
# - Vocabulary size is a design choice that controls how many merges I keep.
#
# **3. Iterate while useful**
# - I repeat counting and merging until I reach my merge budget or gains become negligible.
#
# **Decoding idea**
# - I can reconstruct text by expanding merged IDs back toward byte-level pieces in reverse merge logic.

# %% [markdown]
# &nbsp;
# ## 1.4 BPE algorithm example
#
# ### 1.4.1 Encoding-side toy run
#
# - I use a tiny training string: `the cat in the hat`.
#
# **Iteration 1**
#
# 1. Find most frequent pair
#   - `th` appears twice.
#
# 2. Merge and record
#   - I create `256 -> "th"`.
#   - Sequence becomes: `<256>e cat in <256>e hat`.
#
# ```
# 0: ...
# ...
# 256: "th"
# ```
#
# **Iteration 2**
#
# 1. Find most frequent pair
#   - In `<256>e cat in <256>e hat`, pair `<256>e` appears twice.
#
# 2. Merge and record
#   - I create `257 -> "<256>e"`.
#   - Sequence becomes:
#     ```
#     <257> cat in <257> hat
#     ```
#
# ```
# 0: ...
# ...
# 256: "th"
# 257: "<256>e"
# ```
#
# **Iteration 3**
#
# 1. Find most frequent pair
#   - In `<257> cat in <257> hat`, pair `<257> ` appears twice.
#
# 2. Merge and record
#   - I create `258 -> "<257> "`.
#   - Sequence becomes:
#     ```
#     <258>cat in <258>hat
#     ```
#
# ```
# 0: ...
# ...
# 256: "th"
# 257: "<256>e"
# 258: "<257> "
# ```
#
# - I continue this loop until my merge budget is reached.
#
# &nbsp;
# ### 1.4.2 Decoding-side toy run
#
# - Start from compressed text: `<258>cat in <258>hat`.
# - Expand `<258> -> <257> ` gives: `<257> cat in <257> hat`.
# - Expand `<257> -> <256>e` gives: `<256>e cat in <256>e hat`.
# - Expand `<256> -> th` gives: `the cat in the hat`.

# %% [markdown]
# &nbsp;
# ## 2. A simple BPE implementation

# %% [markdown]
# - Below is my compact `BPETokenizerSimple` class: small enough to inspect, but still complete enough for end-to-end train/encode/decode experiments.
# - I map the flow as: `train()` learns merges, `encode()` applies merge priority, and `decode()` reconstructs text.
#
# 1. Convert input text to byte-level IDs
# 2. Merge adjacent pairs according to learned merge priority
# 3. Stop when no applicable merge remains
# 4. Return the final token IDs

# %%
from collections import Counter, deque
from functools import lru_cache


class BPETokenizerSimple:
    def __init__(self):
        # Maps token_id to token_str (e.g., {11246: "some"})
        self.vocab = {}
        # Maps token_str to token_id (e.g., {"some": 11246})
        self.inverse_vocab = {}
        # Dictionary of BPE merges: {(token_id1, token_id2): merged_token_id}
        self.bpe_merges = {}

    def train(self, text, vocab_size, allowed_special={"<|endoftext|>"}):
        """
        Train the BPE tokenizer from scratch.

        Args:
            text (str): The training text.
            vocab_size (int): The desired vocabulary size.
            allowed_special (set): A set of special tokens to include.
        """

        # Preprocess: Replace spaces with 'Ġ'
        # Note that Ġ is a particularity of the GPT-2 BPE implementation
        # E.g., "Hello world" might be tokenized as ["Hello", "Ġworld"]
        # (GPT-4 BPE would tokenize it as ["Hello", " world"])
        processed_text = []
        for i, char in enumerate(text):
            if char == " " and i != 0:
                processed_text.append("Ġ")
            if char != " ":
                processed_text.append(char)
        processed_text = "".join(processed_text)

        # Initialize vocab with unique characters, including 'Ġ' if present
        # Start with the first 256 ASCII characters
        unique_chars = [chr(i) for i in range(256)]

        # Extend unique_chars with characters from processed_text that are not already included
        unique_chars.extend(char for char in sorted(set(processed_text)) if char not in unique_chars)

        # Optionally, ensure 'Ġ' is included if it is relevant to your text processing
        if 'Ġ' not in unique_chars:
            unique_chars.append('Ġ')

        # Now create the vocab and inverse vocab dictionaries
        self.vocab = {i: char for i, char in enumerate(unique_chars)}
        self.inverse_vocab = {char: i for i, char in self.vocab.items()}

        # Add allowed special tokens
        if allowed_special:
            for token in allowed_special:
                if token not in self.inverse_vocab:
                    new_id = len(self.vocab)
                    self.vocab[new_id] = token
                    self.inverse_vocab[token] = new_id

        # Tokenize the processed_text into token IDs
        token_ids = [self.inverse_vocab[char] for char in processed_text]

        # BPE steps 1-3: Repeatedly find and replace frequent pairs
        for new_id in range(len(self.vocab), vocab_size):
            pair_id = self.find_freq_pair(token_ids, mode="most")
            if pair_id is None:  # No more pairs to merge. Stopping training.
                break
            token_ids = self.replace_pair(token_ids, pair_id, new_id)
            self.bpe_merges[pair_id] = new_id

        # Build the vocabulary with merged tokens
        for (p0, p1), new_id in self.bpe_merges.items():
            merged_token = self.vocab[p0] + self.vocab[p1]
            self.vocab[new_id] = merged_token
            self.inverse_vocab[merged_token] = new_id

    def encode(self, text):
        """
        Encode the input text into a list of token IDs.

        Args:
            text (str): The text to encode.

        Returns:
            List[int]: The list of token IDs.
        """
        tokens = []
        # Split text into tokens, keeping newlines intact
        words = text.replace("\n", " \n ").split()  # Ensure '\n' is treated as a separate token

        for i, word in enumerate(words):
            if i > 0 and not word.startswith("\n"):
                tokens.append("Ġ" + word)  # Add 'Ġ' to words that follow a space or newline
            else:
                tokens.append(word)  # Handle first word or standalone '\n'

        token_ids = []
        for token in tokens:
            if token in self.inverse_vocab:
                # token is contained in the vocabulary as is
                token_id = self.inverse_vocab[token]
                token_ids.append(token_id)
            else:
                # Attempt to handle subword tokenization via BPE
                sub_token_ids = self.tokenize_with_bpe(token)
                token_ids.extend(sub_token_ids)

        return token_ids

    def tokenize_with_bpe(self, token):
        """
        Tokenize a single token using BPE merges.

        Args:
            token (str): The token to tokenize.

        Returns:
            List[int]: The list of token IDs after applying BPE.
        """
        # Tokenize the token into individual characters (as initial token IDs)
        token_ids = [self.inverse_vocab.get(char, None) for char in token]
        if None in token_ids:
            missing_chars = [char for char, tid in zip(token, token_ids) if tid is None]
            raise ValueError(f"Characters not found in vocab: {missing_chars}")

        can_merge = True
        while can_merge and len(token_ids) > 1:
            can_merge = False
            new_tokens = []
            i = 0
            while i < len(token_ids) - 1:
                pair = (token_ids[i], token_ids[i + 1])
                if pair in self.bpe_merges:
                    merged_token_id = self.bpe_merges[pair]
                    new_tokens.append(merged_token_id)
                    # Uncomment for educational purposes:
                    # print(f"Merged pair {pair} -> {merged_token_id} ('{self.vocab[merged_token_id]}')")
                    i += 2  # Skip the next token as it's merged
                    can_merge = True
                else:
                    new_tokens.append(token_ids[i])
                    i += 1
            if i < len(token_ids):
                new_tokens.append(token_ids[i])
            token_ids = new_tokens

        return token_ids

    def decode(self, token_ids):
        """
        Decode a list of token IDs back into a string.

        Args:
            token_ids (List[int]): The list of token IDs to decode.

        Returns:
            str: The decoded string.
        """
        decoded_string = ""
        for token_id in token_ids:
            if token_id not in self.vocab:
                raise ValueError(f"Token ID {token_id} not found in vocab.")
            token = self.vocab[token_id]
            if token.startswith("Ġ"):
                # Replace 'Ġ' with a space
                decoded_string += " " + token[1:]
            else:
                decoded_string += token
        return decoded_string

    @lru_cache(maxsize=None)
    def get_special_token_id(self, token):
        return self.inverse_vocab.get(token, None)

    @staticmethod
    def find_freq_pair(token_ids, mode="most"):
        pairs = Counter(zip(token_ids, token_ids[1:]))

        if mode == "most":
            return max(pairs.items(), key=lambda x: x[1])[0]
        elif mode == "least":
            return min(pairs.items(), key=lambda x: x[1])[0]
        else:
            raise ValueError("Invalid mode. Choose 'most' or 'least'.")

    @staticmethod
    def replace_pair(token_ids, pair_id, new_id):
        dq = deque(token_ids)
        replaced = []

        while dq:
            current = dq.popleft()
            if dq and (current, dq[0]) == pair_id:
                replaced.append(new_id)
                # Remove the 2nd token of the pair, 1st was already removed
                dq.popleft()
            else:
                replaced.append(current)

        return replaced

# %% [markdown]
# - The class implementation is still substantial, so this section emphasizes usage behavior rather than line-by-line internals.

# %% [markdown]
# ## 3. BPE implementation walkthrough

# %% [markdown]
# - For real projects I would choose `tiktoken`; this notebook is intentionally tuned for learning readability.
# - Even so, the core usage pattern is similar enough for intuition transfer.
# - I now test this implementation with small examples to verify how merges change sequence length and decoding behavior.

# %% [markdown]
# ### 3.1 Training, encoding, and decoding

# %% [markdown]
# - First, I\'ll consider some sample text as my training dataset:

# %%
import os
import urllib.request

if not os.path.exists("../01_main-chapter-code/the-verdict.txt"):
    url = ("https://raw.githubusercontent.com/rasbt/"
           "LLMs-from-scratch/main/ch02/01_main-chapter-code/"
           "the-verdict.txt")
    file_path = "../01_main-chapter-code/the-verdict.txt"
    urllib.request.urlretrieve(url, file_path)

with open("../01_main-chapter-code/the-verdict.txt", "r", encoding="utf-8") as f: # added ../01_main-chapter-code/
    text = f.read()

# %% [markdown]
# - Next, I\'ll initialize and train the BPE tokenizer with a vocabulary size of 1,000
# - Note that the vocabulary size is already 255 by default due to the byte values discussed earlier, so I am only "learning" 745 vocabulary entries
# - For comparison, the GPT-2 vocabulary is 50,257 tokens, the GPT-4 vocabulary is 100,256 tokens (`cl100k_base` in tiktoken), and GPT-4o uses 199,997 tokens (`o200k_base` in tiktoken); they have all much bigger training sets compared to my simple example text above

# %%
tokenizer = BPETokenizerSimple()
tokenizer.train(text, vocab_size=1000, allowed_special={"<|endoftext|>"})

# %% [markdown]
# - I can print the full vocabulary, but I usually inspect size first because full dumps are very long.

# %%
# print(tokenizer.vocab)
print(len(tokenizer.vocab))

# %% [markdown]
# - This vocabulary is created by merging 742 times (~ `1000 - len(range(0, 256))`)

# %%
print(len(tokenizer.bpe_merges))

# %% [markdown]
# - This means that the first 256 entries are single-character tokens

# %% [markdown]
# - Next, I\'ll use the created merges via the `encode` method to encode some text:

# %%
input_text = "Jack embraced beauty through art and life."
token_ids = tokenizer.encode(input_text)
print(token_ids)

# %%
print("Number of characters:", len(input_text))
print("Number of token IDs:", len(token_ids))

# %% [markdown]
# - From the lengths above, I can see that a 42-character sentence was encoded into 20 token IDs, effectively cutting the input length roughly in half compared to a character-byte-based encoding

# %% [markdown]
# - Decoding uses the learned vocabulary mapping, so this check tells me whether encode/decode consistency is intact.

# %%
print(token_ids)

# %%
print(tokenizer.decode(token_ids))

# %% [markdown]
# - I inspect each token ID individually to see what text chunk it represents and to understand merge granularity.

# %%
for token_id in token_ids:
    print(f"{token_id} -> {tokenizer.decode([token_id])}")

# %% [markdown]
# - As I can see, most token IDs represent 2-character subwords; that's because the training data text is very short with not that many repetitive words, and because we used a relatively small vocabulary size

# %% [markdown]
# - My quick correctness rule: `decode(encode(text))` should reconstruct the original text for normal inputs.

# %%
tokenizer.decode(tokenizer.encode("This is some text."))

# %% [markdown]
# &nbsp;
# # 4. Conclusion

# %% [markdown]
# - My takeaway: even this stripped-down implementation makes the merge-learning intuition very concrete.
# - I now have a simple training-to-decoding pipeline that I can debug and extend.
#
# **This notebook stays intentionally minimal for learning clarity. For a richer and more robust implementation, see [bpe-from-scratch.ipynb](bpe-from-scratch.ipynb).**
